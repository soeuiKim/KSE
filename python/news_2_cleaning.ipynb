# %%
import pandas as pd

# %%
news_df = pd.read_csv('./news_1_cleaning.csv', encoding='cp949', sep='\t', engine='python', index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8376/2174982470.py in <module>
# ----> 1 news_df = pd.read_csv('./news_1_cleaning.csv', encoding='cp949', sep='\t', engine='python', index = False)
#
# c:\developer\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
news_df.shape
# Out:
# (4606, 1)

# %%
news_df.head()
# Out:
#   태풍,찬투,한반도,가능성,영향,크기,찬투,태풍,진로,방향,관심,한상,기상청,기상,전문관,,정례,예보브리핑,발생,찬투,태풍,동쪽,필리핀,마닐라,부근,해상,시속,속도,서진,중심,부근,최대,풍속,초속,53m,매우강,강도,초속,55m,태풍,발달,예상,찬투,크기,태풍,,초속,920hPa,중심,최대,풍속,초속,55m,,중심,기압,920hPa,최고,등급,태풍,분류,전망,중심,강풍,반경,형성,태풍,조건,기상청,찬투,고기압,북쪽,아열대,바람,시계,방향,필리핀,북동쪽,,대만,남쪽,,남동쪽,중국,푸저우,남동,,순차적,정확,예보,태풍,일본,,바다,한반도,간접적,영향,북서쪽,공기,태풍,고온,다습,공기,기간,폭우,가능성,한상,기상청,기상,전문관,찬투,30도,지역,발달,태풍,공기,가능성,,태풍,진로,예보,기상,강수량,반영,,태풍,변동,만큼,예보,주시,당부,객원기자,장지민,한경닷컴,객원,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8376/2518087616.py in <module>
# ----> 1 news_df.drop[1]
#
# TypeError: 'method' object is not subscriptable
